# %% [markdown]
# 1. Write a Pandas program to import excel data (coalpublic2013.xlsx ) into a Pandas dataframe

# %%
import pandas as pd
import numpy as np

# %%
! pip install openpyxl

# %%
# !pip install --upgrade pandas

# %%
pip install xlrd==1.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Jay' is not recognized as an internal or external command,
# operable program or batch file.

# %%
coalpubli=pd.read_excel('coalpublic2013.xlsx',engine='openpyxl')
coalpubli.head()
# Out:
#    Year  MSHA ID                       Mine_Name  Production  Labor_Hours
# 0  2013   103381            Tacoa Highwall Miner       56004        22392
# 1  2013   103404                Reid School Mine       28807        28447
# 2  2013   100759  North River #1 Underground Min     1440115       474784
# 3  2013   103246                      Bear Creek       87587        29193
# 4  2013   103451                     Knight Mine      147499        46393

# %% [markdown]
# Write a Pandas program to insert a column in the sixth position of the said excel sheet and fill it with NaN value

# %%
coalpubli.insert(5,"New_col",value=np.nan)

# %%
coalpubli
# Out:
#     Year  MSHA ID                       Mine_Name  Production  Labor_Hours  \
# 0   2013   103381            Tacoa Highwall Miner       56004        22392
# 1   2013   103404                Reid School Mine       28807        28447
# 2   2013   100759  North River #1 Underground Min     1440115       474784
# 3   2013   103246                      Bear Creek       87587        29193
# 4   2013   103451                     Knight Mine      147499        46393
# 5   2013   103433              Crane Central Mine       69339        47195
# 6   2013   100329                    Concord Mine           0       144002
# 7   2013   100851                  Oak Grove Mine     2269014      1001809
# 8   2013   102901                Shoal Creek Mine           0        12396
# 9   2013   102901                Shoal Creek Mine     1453024      1237415
# 10  2013   103180             Sloan Mountain Mine      327780       196963
# ...

# %% [markdown]
#    Write a Pandas program to import some excel data (coalpublic2013.xlsx ) skipping first twenty rows into a Pandas dataframe

# %%
skip_row=pd.read_excel('coalpublic2013.xlsx',skiprows=20)

# %%
skip_row
# Out:
#     2013   102976   Piney Woods Preparation Plant        0    23193
# 0   2013   103380                          Calera        0    12621
# 1   2013   103380                          Calera        0     1402
# 2   2013   103422                 Clark No 1 Mine   122727   140250
# 3   2013   103467             Helena Surface Mine    59664    30539
# 4   2013   101247                       No 4 Mine  2622528  1551141
# 5   2013   101401                       No 7 Mine  5405412  2464719
# 6   2013   103172  Searles Mine No. 2, 3, 4, 5, 6   258078   119542
# 7   2013   103179             Fleetwood Mine No 1    75937    63745
# 8   2013   103303                    Shannon Mine   317491   164388
# 9   2013   103323                   Deerlick Mine   133452    46381
# 10  2013   103364           Brc Alabama No. 7 Llc        0    14324
# 11  2013   103436                Swann's Crossing   137511    77190
# 12  2013   100347                    Choctaw Mine   537429   215295
# ...

# %% [markdown]
#  Write a Pandas program to add summation to a row of the given excel file

# %%
coalpubli.head()
# Out:
#    Year  MSHA ID                       Mine_Name  Production  Labor_Hours  \
# 0  2013   103381            Tacoa Highwall Miner       56004        22392
# 1  2013   103404                Reid School Mine       28807        28447
# 2  2013   100759  North River #1 Underground Min     1440115       474784
# 3  2013   103246                      Bear Creek       87587        29193
# 4  2013   103451                     Knight Mine      147499        46393
#
#    New_col
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
coalpubli['Labor_Hours'].sum()
# Out:
# 11098816

# %% [markdown]
# Write a Pandas program to create a subtotal of "Labor Hours" against MSHA ID from the given excel data (coalpublic2013.xlsx )

# %%
coalpubli['MSHA ID'].unique()
# Out:
# array([ 103381,  103404,  100759,  103246,  103451,  103433,  100329,
#         100851,  102901,  103180,  103182,  103285,  103332,  103375,
#         103419,  103432,  103437,  102976,  103380,  103422,  103467,
#         101247,  101401,  103172,  103179,  103303,  103323,  103364,
#         103436,  100347,  101362,  102996,  103155,  103195,  103342,
#         103370,  103372,  103376,  103389,  103410,  103423, 1519322,
#         103321,  103358, 5000030,  201195], dtype=int64)

# %%
coalpubli['MSHA ID'].value_counts()
# Out:
# 103380     2
# 102976     2
# 102901     2
# 103155     2
# 103381     1
# 103342     1
# 103364     1
# 103436     1
# 100347     1
# 101362     1
# 102996     1
# 103195     1
# 103370     1
# 103303     1
# 103372     1
# 103376     1
# 103389     1
# 103410     1
# 103423     1
# 1519322    1
# 103321     1
# 103358     1
# 5000030    1
# 103323     1
# 103172     1
# 103179     1
# 103285     1
# 100759     1
# 103246     1
# 103451     1
# 103433     1
# 100329     1
# 100851     1
# 103180     1
# 103182     1
# 103332     1
# 103404     1
# 103375     1
# 103419     1
# 103432     1
# 103437     1
# 103422     1
# 103467     1
# 101247     1
# 101401     1
# 201195     1
# Name: MSHA ID, dtype: int64

# %%
coalpubli.groupby('MSHA ID')['Labor_Hours'].sum()
# Out:
# MSHA ID
# 100329      144002
# 100347      215295
# 100759      474784
# 100851     1001809
# 101247     1551141
# 101362      116914
# 101401     2464719
# 102901     1249811
# 102976       38021
# 102996      164093
# 103155       79990
# 103172      119542
# 103179       63745
# 103180      196963
# 103182       87314
# 103195       17411
# 103246       29193
# 103285       90584
# 103303      164388
# 103321       76366
# 103323       46381
# 103332       61394
# 103342      115123
# 103358      161805
# 103364       14324
# 103370         621
# 103372       32401
# 103375        1900
# 103376      176499
# 103380       14023
# 103381       22392
# 103389       84966
# 103404       28447
# 103410      158591
# 103419      107469
# 103422      140250
# 103423        9162
# 103432         220
# 103433       47195
# 103436       77190
# 103437       70926
# 103451       46393
# 103467       30539
# 201195     1015333
# 1519322       3108
# 5000030     286079
# ...

# %% [markdown]
# Write a Pandas program to import excel data (coalpublic2013.xlsx ) into a dataframe and find details where "Labor Hours" > 20000

# %%
coalpubli[coalpubli['Labor_Hours']>2000].sort_values(by=['Labor_Hours'])
# Out:
#     Year  MSHA ID                       Mine_Name  Production  Labor_Hours  \
# 45  2013  1519322                         Ghm #25       25054         3108
# 44  2013   103423                Dutton Hill Mine       37275         9162
# 8   2013   102901                Shoal Creek Mine           0        12396
# 20  2013   103380                          Calera           0        12621
# 30  2013   103364           Brc Alabama No. 7 Llc           0        14324
# 18  2013   102976   Piney Woods Preparation Plant           0        14828
# 37  2013   103195     Mccollum/Sparks Branch Mine       71910        17411
# 0   2013   103381            Tacoa Highwall Miner       56004        22392
# 19  2013   102976   Piney Woods Preparation Plant           0        23193
# 35  2013   103155              Corinth Prep Plant           0        27996
# 1   2013   103404                Reid School Mine       28807        28447
# ...

# %% [markdown]
# 12. Write a Pandas program to import excel data (coalpublic2013.xlsx ) into a dataframe and find details where "Mine Name" starts with "P".

# %%
coalpubli[coalpubli['Mine_Name'].map(lambda x:x.startswith('P'))]
# Out:
#     Year  MSHA ID                      Mine_Name  Production  Labor_Hours  \
# 13  2013   103332                  Powhatan Mine      140521        61394
# 18  2013   102976  Piney Woods Preparation Plant           0        14828
# 19  2013   102976  Piney Woods Preparation Plant           0        23193
# 46  2013   103321                 Poplar Springs      189370        76366
#
#     New_col
# 13      NaN
# 18      NaN
# 19      NaN
# 46      NaN

# %% [markdown]
# Write a Pandas program to import given excel data (coalpublic2013.xlsx ) into a Pandas dataframe and find a list of specified customers by name

# %%
coalpubli.query('Mine_Name == ["Shoal Creek Mine", "Piney Woods Preparation Plant"]').head()
# Out:
#     Year  MSHA ID                      Mine_Name  Production  Labor_Hours  \
# 8   2013   102901               Shoal Creek Mine           0        12396
# 9   2013   102901               Shoal Creek Mine     1453024      1237415
# 18  2013   102976  Piney Woods Preparation Plant           0        14828
# 19  2013   102976  Piney Woods Preparation Plant           0        23193
#
#     New_col
# 8       NaN
# 9       NaN
# 18      NaN
# 19      NaN

# %% [markdown]
# Write a Pandas program to import excel data (employee.xlsx ) into a Pandas dataframe and find a list of employees where hire_date> 01-01-07.

# %%
df=pd.read_excel('employee.xlsx')

# %%
df.head()
# Out:
#    emp_id first_name last_name  hire_date
# 0     100     Steven      King 2003-06-17
# 1     101      Neena   Kochhar 2005-09-21
# 2     102        Lex   De Haan 2001-01-13
# 3     103  Alexander    Hunold 2006-01-03
# 4     104      Bruce     Ernst 2007-05-21

# %%
df.dtypes
# Out:
# emp_id                 int64
# first_name            object
# last_name             object
# hire_date     datetime64[ns]
# dtype: object

# %%
df[df['hire_date']>'01-01-07']
# Out:
#     emp_id first_name   last_name  hire_date
# 4      104      Bruce       Ernst 2007-05-21
# 7      107      Diana     Lorentz 2007-02-07
# 13     113       Luis        Popp 2007-12-07
# 19     119      Karen  Colmenares 2007-08-10

# %% [markdown]
# Write a Pandas program to import excel data (employee.xlsx ) into a Pandas dataframe and find a list of employees where hire_date between two specific month and year.

# %%
result = df[(df['hire_date'] >='Jan-2005') & (df['hire_date'] <= 'Dec-2006')].head()
result
# Out:
#     emp_id first_name  last_name  hire_date
# 1      101      Neena    Kochhar 2005-09-21
# 3      103  Alexander     Hunold 2006-01-03
# 5      105      David     Austin 2005-06-25
# 6      106      Valli  Pataballa 2006-02-05
# 10     110       John       Chen 2005-09-28

# %% [markdown]
# Write a Pandas program to import given excel data (employee.xlsx ) into a Pandas dataframe and sort based on multiple given columns.

# %%
result = df.sort_values(by=['first_name','last_name'],ascending=[0,1])
result
# Out:
#     emp_id   first_name   last_name  hire_date
# 6      106        Valli   Pataballa 2006-02-05
# 0      100       Steven        King 2003-06-17
# 17     117        Sigal      Tobias 2005-07-24
# 16     116       Shelli       Baida 2005-12-24
# 1      101        Neena     Kochhar 2005-09-21
# 8      108        Nancy   Greenberg 2002-08-17
# 13     113         Luis        Popp 2007-12-07
# 2      102          Lex     De Haan 2001-01-13
# 19     119        Karen  Colmenares 2007-08-10
# 12     112  Jose Manuel       Urman 2006-03-07
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 18     118          Guy      Himuro 2006-11-15
# 7      107        Diana     Lorentz 2007-02-07
# 14     114          Den    Raphaely 2002-12-07
# 5      105        David      Austin 2005-06-25
# 9      109       Daniel      Faviet 2002-08-16
# 4      104        Bruce       Ernst 2007-05-21
# 3      103    Alexander      Hunold 2006-01-03
# ...

# %% [markdown]
# Write a Pandas program to import sheet2 data from a given excel data (employee.xlsx ) into a Pandas dataframe.

# %%
df1 = pd.read_excel('employee.xlsx',sheet_name=1)
print(df1)
# Out:
#     emp_id first_name    last_name  hire_date
# 0      120    Matthew        Weiss 2004-07-18
# 1      121       Adam        Fripp 2005-04-10
# 2      122      Payam     Kaufling 2003-05-01
# 3      123     Shanta      Vollman 2005-10-10
# 4      124      Kevin      Mourgos 2007-11-16
# 5      125      Julia        Nayer 2005-07-16
# 6      126      Irene  Mikkilineni 2006-09-28
# 7      127      James       Landry 2007-01-14
# 8      128     Steven       Markle 2008-03-08
# 9      129      Laura       Bissot 2005-08-20
# 10     130      Mozhe     Atkinson 2005-10-30
# 11     131      James       Marlow 2005-02-16
# 12     132         TJ        Olson 2007-04-10
# 13     133      Jason       Mallin 2004-06-14
# 14     134    Michael       Rogers 2006-08-26
# 15     135         Ki          Gee 2007-12-12
# 16     136      Hazel   Philtanker 2008-02-06
# 17     137     Renske       Ladwig 2003-07-14
# 18     138    Stephen       Stiles 2005-10-26

# %%
df2 = pd.read_excel('employee.xlsx',sheet_name=0)
print(df2)
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      100       Steven        King 2003-06-17
# 1      101        Neena     Kochhar 2005-09-21
# 2      102          Lex     De Haan 2001-01-13
# 3      103    Alexander      Hunold 2006-01-03
# 4      104        Bruce       Ernst 2007-05-21
# 5      105        David      Austin 2005-06-25
# 6      106        Valli   Pataballa 2006-02-05
# 7      107        Diana     Lorentz 2007-02-07
# 8      108        Nancy   Greenberg 2002-08-17
# 9      109       Daniel      Faviet 2002-08-16
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 12     112  Jose Manuel       Urman 2006-03-07
# 13     113         Luis        Popp 2007-12-07
# 14     114          Den    Raphaely 2002-12-07
# 15     115    Alexander        Khoo 2003-05-18
# 16     116       Shelli       Baida 2005-12-24
# 17     117        Sigal      Tobias 2005-07-24
# 18     118          Guy      Himuro 2006-11-15
# ...

# %%
df = pd.read_excel('employee.xlsx',sheet_name=2)
print(df)
# Out:
#    emp_id first_name  last_name  hire_date
# 0     141     Trenna       Rajs 2003-10-17
# 1     142     Curtis     Davies 2005-01-29
# 2     143    Randall      Matos 2006-03-15
# 3     144      Peter     Vargas 2006-07-09
# 4     145       John    Russell 2004-10-01
# 5     146      Karen   Partners 2005-01-05
# 6     147    Alberto  Errazuriz 2005-03-10
# 7     148     Gerald  Cambrault 2007-10-15
# 8     149      Eleni    Zlotkey 2008-01-29

# %% [markdown]
# Write a Pandas program to import three datasheets from a given excel data (coalpublic2013.xlsx ) and combine in to a single dataframe.

# %%
df3 = pd.read_excel('employee.xlsx',sheet_name=0)
df4 = pd.read_excel('employee.xlsx',sheet_name=1)
df5 = pd.read_excel('employee.xlsx',sheet_name=2)
df6= pd.concat([df1, df2, df3])
print(df6)
# Note: Structure of the three datasheets are same.
# Out:
#     emp_id   first_name    last_name  hire_date
# 0      120      Matthew        Weiss 2004-07-18
# 1      121         Adam        Fripp 2005-04-10
# 2      122        Payam     Kaufling 2003-05-01
# 3      123       Shanta      Vollman 2005-10-10
# 4      124        Kevin      Mourgos 2007-11-16
# 5      125        Julia        Nayer 2005-07-16
# 6      126        Irene  Mikkilineni 2006-09-28
# 7      127        James       Landry 2007-01-14
# 8      128       Steven       Markle 2008-03-08
# 9      129        Laura       Bissot 2005-08-20
# 10     130        Mozhe     Atkinson 2005-10-30
# 11     131        James       Marlow 2005-02-16
# 12     132           TJ        Olson 2007-04-10
# 13     133        Jason       Mallin 2004-06-14
# 14     134      Michael       Rogers 2006-08-26
# 15     135           Ki          Gee 2007-12-12
# 16     136        Hazel   Philtanker 2008-02-06
# 17     137       Renske       Ladwig 2003-07-14
# 18     138      Stephen       Stiles 2005-10-26
# ...
