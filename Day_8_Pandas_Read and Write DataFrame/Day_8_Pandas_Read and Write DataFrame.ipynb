# %% [markdown]
# # Pandas:

# %% [markdown]
# ## Advantages of Pandas Library

# %% [markdown]
# 1. Data interepretation:
#
# - Pandas is extremely usefull when it's comes to data interpretation and representing the data in extremely streamlined manner.
#
# 2. less writing and more work done:
#
# 3. Extensive set of ferautes:
#
# - Pandas comes with hugh features which are used to analyze the data very effectively.
#
# - We can filter the data, group and also segmenting and segregating the data as per the our preference.
#
# 4. Efficiently handles large data:
#
# - One of the best features of pandas is effectively managing the large set of data such that we can add, edit, delete and pivot it as per our requirements.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Pandas is an open-source python library that is used for data manipulation and analysis.
#
# - It provides many functions and methods to speed up the data analysis process.
#
# - Pandas is built on top of the NumPy package, hence it takes a lot of basic inspiration from it

# %% [markdown]
#  - The two primary data structures are Series which is 1 dimensional and DataFrame which is 2 dimensional.

# %% [markdown]
# - Series are like columns while Dataframes are your full blown tables in Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Read

# %%
import os

# %%
df=pd.read_csv('police.csv')

# %% [markdown]
# # 2. Head()

# %%
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# # 3.shape

# %%
df.shape
# Out:
# (91741, 15)

# %% [markdown]
# # 4. Info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %% [markdown]
# # 5. to_datetime()

# %%
import datetime as dt
df['stop_date']=pd.to_datetime(df['stop_date'])

# %%
df['stop_time']=pd.to_datetime(df['stop_time']).dt.time

# %%
df[['stop_date','stop_time']]
# Out:
#        stop_date stop_time
# 0     2005-01-02  01:55:00
# 1     2005-01-18  08:15:00
# 2     2005-01-23  23:15:00
# 3     2005-02-20  17:15:00
# 4     2005-03-14  10:00:00
# ...          ...       ...
# 91736 2015-12-31  20:27:00
# 91737 2015-12-31  20:35:00
# 91738 2015-12-31  20:45:00
# 91739 2015-12-31  21:42:00
# 91740 2015-12-31  22:46:00
#
# [91741 rows x 2 columns]

# %% [markdown]
# # 6.isnull()

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# # 7.drop()

# %% [markdown]
# - Now, as we can see that “county_name” column is completely empty, so it will not provide any information which is beneficial to us. Hence, we will drop that particular column using the pandas “drop()” function

# %%
df.drop(['county_name'],axis=1,inplace=True)

# %% [markdown]
# # 8. describe()

# %%
df.describe()
# Out:
#        driver_age_raw    driver_age
# count    86414.000000  86120.000000
# mean      1970.491228     34.011333
# std        110.914909     12.738564
# min          0.000000     15.000000
# 25%       1967.000000     23.000000
# 50%       1980.000000     31.000000
# 75%       1987.000000     43.000000
# max       8801.000000     99.000000

# %% [markdown]
# # 9. value_counts()
# - Now, as we can see that “county_name” column is completely empty, so it will not provide any information which is beneficial to us. Hence, we will drop that particular column using the pandas “drop()” function

# %%
df['search_type'].value_counts()
# Out:
# Incident to Arrest                                          1219
# Probable Cause                                               891
# Inventory                                                    220
# Reasonable Suspicion                                         197
# Protective Frisk                                             161
# Incident to Arrest,Inventory                                 129
# Incident to Arrest,Probable Cause                            106
# Probable Cause,Reasonable Suspicion                           75
# Incident to Arrest,Inventory,Probable Cause                   34
# Incident to Arrest,Protective Frisk                           33
# Probable Cause,Protective Frisk                               33
# Inventory,Probable Cause                                      22
# Incident to Arrest,Reasonable Suspicion                       13
# Protective Frisk,Reasonable Suspicion                         11
# ...

# %% [markdown]
# # 10.fillna()

# %%
df['driver_gender'].isnull().sum()
# Out:
# 5335

# %%
df['driver_gender'].fillna(df['driver_gender'].mode,inplace=True)

# %%
df['driver_gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 11. sample()

# %%
df.sample(20)
# Out:
#        stop_date stop_time                                      driver_gender  \
# 48631 2011-04-01  09:30:00                                                  M
# 66230 2013-01-10  12:40:00                                                  M
# 30556 2008-11-20  23:07:00                                                  M
# 18088 2007-06-22  08:15:00                                                  M
# 8771  2006-07-31  15:35:00                                                  F
# 77864 2014-05-29  06:37:00                                                  M
# 89627 2015-09-29  06:57:00                                                  M
# 60026 2012-05-19  09:06:00                                                  M
# 60600 2012-06-04  16:10:00                                                  M
# 25610 2008-05-06  09:59:00                                                  F
# 468   2005-10-19  08:05:00                                                  M
# ...

# %% [markdown]
# # 12.nunique()

# %%
df['driver_race'].nunique()
# Out:
# 5

# %% [markdown]
# - nunique()” function to find the no. of unique values in our series or data frame. Generally, it is used in the case of categorical features to identify the no. of categories in a particular feature.

# %% [markdown]
# # 13.columns

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_age_raw',
#        'driver_age', 'driver_race', 'violation_raw', 'violation',
#        'search_conducted', 'search_type', 'stop_outcome', 'is_arrested',
#        'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %% [markdown]
# # 14.nsmallest & nlargest

# %%
df.nsmallest(4,'driver_age')
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 10500 2006-09-30  01:30:00             M          1991.0        15.0
# 17771 2007-06-11  12:30:00             M          1992.0        15.0
# 18357 2007-07-04  00:40:00             F          1992.0        15.0
# 25294 2008-04-21  11:19:00             M          1993.0        15.0
#
#       driver_race            violation_raw         violation  \
# 10500       Black  Other Traffic Violation  Moving violation
# 17771       White                 Speeding          Speeding
# 18357       White  Other Traffic Violation  Moving violation
# 25294    Hispanic  Other Traffic Violation  Moving violation
#
#        search_conducted         search_type   stop_outcome is_arrested  \
# 10500             False                 NaN  Arrest Driver        True
# 17771             False                 NaN       Citation       False
# 18357             False                 NaN  Arrest Driver        True
# ...

# %%
df.nlargest(10,'driver_age')
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 71539 2013-09-08  09:50:00             F          1914.0        99.0
# 75037 2014-02-14  10:21:00             M          1920.0        94.0
# 76956 2014-04-25  16:40:00             M          1924.0        90.0
# 74348 2014-01-18  13:07:00             F          1925.0        89.0
# 9829  2006-09-06  12:15:00             M          1918.0        88.0
# 50377 2011-06-20  12:05:00             M          1923.0        88.0
# 68142 2013-04-06  10:48:00             M          1926.0        87.0
# 70699 2013-08-02  14:35:00             M          1926.0        87.0
# 74474 2014-01-23  20:30:00             M          1927.0        87.0
# 76675 2014-04-15  08:15:00             M          1927.0        87.0
#
#       driver_race                   violation_raw         violation  \
# 71539       White         Other Traffic Violation  Moving violation
# 75037       White         Other Traffic Violation  Moving violation
# ...

# %% [markdown]
# # 15.groupby()

# %%
df.groupby('driver_race').mean()
# Out:
#              driver_age_raw  driver_age  search_conducted  drugs_related_stop
# driver_race
# Asian           1971.271802   33.579672          0.022576            0.004869
# Black           1970.870549   33.110519          0.064521            0.016416
# Hispanic        1974.886072   31.565369          0.061428            0.013253
# Other           1967.025000   34.548117          0.012500            0.004167
# White           1969.792239   34.576958          0.028444            0.007658

# %% [markdown]
# # 16. get_group()

# %%
df.groupby('driver_race').get_group('Black')
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 5     2005-03-23  09:45:00             M          1982.0        23.0
# 8     2005-07-13  10:15:00             M          1970.0        35.0
# 22    2005-08-08  02:09:00             M          1955.0        50.0
# 30    2005-09-26  12:09:00             M          1959.0        46.0
# 64    2005-10-01  20:00:00             M          1972.0        33.0
# ...          ...       ...           ...             ...         ...
# 91653 2015-12-27  22:44:00             M          1968.0        47.0
# 91692 2015-12-29  23:25:00             M          1987.0        28.0
# 91696 2015-12-30  07:32:00             F          1967.0        48.0
# 91701 2015-12-30  09:49:00             F          1991.0        24.0
# 91722 2015-12-31  07:06:00             M          1970.0        45.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
# 17. loc() and iloc(*)
